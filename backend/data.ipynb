# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_main = pd.read_csv('../data/cancer_patient_data_sets.csv')
df_main.columns

heatmap = plt.matshow(df_main, cmap='coolwarm')
plt.colorbar(heatmap)

plt.xticks(range(df_main.shape[1]), df_main.columns)
plt.yticks(range(df_main.shape[0]), df_main.index)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\danie\Downloads\VS_CODE_PROJECTS\2023Datathon\backend\data.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Downloads/VS_CODE_PROJECTS/2023Datathon/backend/data.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df_main = pd.read_csv('../data/cancer_patient_data_sets.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Downloads/VS_CODE_PROJECTS/2023Datathon/backend/data.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df_main.columns
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Downloads/VS_CODE_PROJECTS/2023Datathon/backend/data.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> heatmap = plt.matshow(df_main, cmap='coolwarm')
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Downloads/VS_CODE_PROJECTS/2023Datathon/backend/data.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> plt.colorbar(heatmap)
# ...
