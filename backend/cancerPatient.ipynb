# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_main = pd.read_csv('../data/cancer_patient_data_sets.csv')
df_main.columns

df = df_main.drop(['Patient Id','Level','index'], axis=1)


# Calculate the correlation matrix
correlation_matrix = df.corr()

plt.figure(figsize=(12, 10))  # Set the figure size (optional)
sns.heatmap(correlation_matrix, cmap='coolwarm', linewidths=.5)

# Show the heatmap
plt.show()
